# %% [markdown]
# A DIVISION
# #TEAM 13: Detecting Natural Disasters
# * Muskan R Havaldar - 01fe19bcs007
# * Shubham Khobare - 01fe19bcs047
# * Rohit Hegde - 01fe19bcs058
# * Akhilesh Naik - 01fe19bcs066

# %%
from google.colab import drive
drive.mount('/content/drive') 
# !ls "/content/drive/My Drive"
# Out:
# Mounted at /content/drive
#  archive.zip  'Colab Notebooks'   model   model1.h5

# %%
# !unzip 'drive/MyDrive/archive.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/610.jpg
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/611.jpg
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/612.jpg
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/613.jpg
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/614.jpg
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/615.jpg
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/616.jpg
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/617.jpg
#   inflating: archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/618.jpg
# ...

# %% [markdown]
# Create new directories for train, test and validation images.

# %%
import os
import shutil

# model_dir = 'archive/DisasterModel'

# cyclone_dir = r'archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Cyclone'
# earthquake_dir = r'archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake'
# flood_dir = r'archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Flood'
# wildfire_dir = r'archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Wildfire'

# train = os.path.join(model_dir, 'train')
# validation = os.path.join(model_dir, 'validation')
# test = os.path.join(model_dir, 'test')

# train_c = os.path.join(train, 'cyclone')
# train_e = os.path.join(train, 'earthquake')
# train_f = os.path.join(train, 'flood')
# train_w = os.path.join(train, 'wildfire')

# validation_c = os.path.join(validation, 'cyclone')
# validation_e = os.path.join(validation, 'earthquake')
# validation_f = os.path.join(validation, 'flood')
# validation_w = os.path.join(validation, 'wildfire')

# test_c = os.path.join(test, 'cyclone')
# test_e = os.path.join(test, 'earthquake')
# test_f = os.path.join(test, 'flood')
# test_w = os.path.join(test, 'wildfire')

# create_dirs = False  #True to create directories

# if create_dirs:
#     os.mkdir(train)
#     os.mkdir(validation)
#     os.mkdir(test)
#     os.mkdir(train_c)
#     os.mkdir(train_e)
#     os.mkdir(train_f)
#     os.mkdir(train_w)
#     os.mkdir(validation_c)
#     os.mkdir(validation_e)
#     os.mkdir(validation_f)
#     os.mkdir(validation_w)
#     os.mkdir(test_c)
#     os.mkdir(test_e)
#     os.mkdir(test_f)
#     os.mkdir(test_w)


# copy_images = False #True to create train test and validation data set by copying images

# if copy_images:

#     # TRAIN

#     names = ['{}.jpg'.format(i) for i in range(400)]
#     for name in names:
#         source = os.path.join(cyclone_dir, name)
#         destination = os.path.join(train_c, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(400)]
#     for name in names:
#         source = os.path.join(earthquake_dir, name)
#         destination = os.path.join(train_e, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(400)]
#     for name in names:
#         source = os.path.join(flood_dir, name)
#         destination = os.path.join(train_f, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(400)]
#     for name in names:
#         source = os.path.join(wildfire_dir, name)
#         destination = os.path.join(train_w, name)
#         shutil.copyfile(source, destination)

#     # VALIDATION

#     names = ['{}.jpg'.format(i) for i in range(400, 500)]
#     for name in names:
#         source = os.path.join(cyclone_dir, name)
#         destination = os.path.join(validation_c, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(400, 500)]
#     for name in names:
#         source = os.path.join(earthquake_dir, name)
#         destination = os.path.join(validation_e, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(400, 500)]
#     for name in names:
#         source = os.path.join(flood_dir, name)
#         destination = os.path.join(validation_f, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(400, 500)]
#     for name in names:
#         source = os.path.join(wildfire_dir, name)
#         destination = os.path.join(validation_w, name)
#         shutil.copyfile(source, destination)

#     # TEST

#     names = ['{}.jpg'.format(i) for i in range(500, 600)]
#     for name in names:
#         source = os.path.join(cyclone_dir, name)
#         destination = os.path.join(test_c, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(500, 600)]
#     for name in names:
#         source = os.path.join(earthquake_dir, name)
#         destination = os.path.join(test_e, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(500, 600)]
#     for name in names:
#         source = os.path.join(flood_dir, name)
#         destination = os.path.join(test_f, name)
#         shutil.copyfile(source, destination)
#     names = ['{}.jpg'.format(i) for i in range(500, 600)]
#     for name in names:
#         source = os.path.join(wildfire_dir, name)
#         destination = os.path.join(test_w, name)
#         shutil.copyfile(source, destination)

# %%
path = "archive_new"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/test"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/train"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/validation"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Cyclone"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Flood"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Wildfire"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/test/cyclone"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/test/earthquake"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/test/flood"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/test/wildfire"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/train/cyclone"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/train/earthquake"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/train/flood"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/train/wildfire"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/validation/cyclone"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/validation/earthquake"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/validation/flood"
os.mkdir(path)

# %%
path = "archive_new/DisasterModel/validation/wildfire"
os.mkdir(path)

# %% [markdown]
# #RESIZE IMAGES TO (224,224)

# %% [markdown]
# RESIZE C_W_F_E

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Cyclone/"

to = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Cyclone/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 928 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/"

to = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 1350 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Flood/"

to = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Flood/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 1073 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Wildfire/"

to = "archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Wildfire/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 1077 no. of images!!

# %% [markdown]
# RESIZE TEST

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/test/cyclone/"

to = "archive_new/DisasterModel/test/cyclone/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 100 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/test/earthquake/"

to = "archive_new/DisasterModel/test/earthquake/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 100 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/test/flood/"

to = "archive_new/DisasterModel/test/flood/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 100 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/test/wildfire/"

to = "archive_new/DisasterModel/test/wildfire/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 100 no. of images!!

# %% [markdown]
# RESIZE TRAIN

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/train/cyclone/"

to = "archive_new/DisasterModel/train/cyclone/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 400 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/train/earthquake/"

to = "archive_new/DisasterModel/train/earthquake/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 400 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/train/flood/"

to = "archive_new/DisasterModel/train/flood/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 400 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/train/wildfire/"

to = "archive_new/DisasterModel/train/wildfire/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 400 no. of images!!

# %% [markdown]
# RESIZE VALIDATION

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/validation/cyclone/"

to = "archive_new/DisasterModel/validation/cyclone/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 100 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/validation/earthquake/"

to = "archive_new/DisasterModel/validation/earthquake/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 100 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/validation/flood/"

to = "archive_new/DisasterModel/validation/flood/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 100 no. of images!!

# %%
import os
import shutil
import sys
from PIL import Image
myfrom = "archive/DisasterModel/validation/wildfire/"

to = "archive_new/DisasterModel/validation/wildfire/"

print("COPYING IN PROGRESS...")
for root, dirs, files in os.walk(myfrom): 
   for file in files:
      path_file = os.path.join(root,file)
      shutil.copy2(path_file,to)
print("COPYING COMPLETED!")

def resize():
    dir = os.listdir( to )
    count = 0
    for image in dir:
      count = count + 1
      # if os.path.isfile(path+image):
      im = Image.open(to+image)
      f, e = os.path.splitext(to+image)
      imResize = im.resize((224,224), Image.ANTIALIAS)
      imResize = imResize.convert('RGB')
      if os.path.exists(to+image):
        os.remove(to+image)
      else:
        print("The file does not exist")
      imResize.save(f + '_resized.jpg', 'JPEG', quality=90)

    return count

print("RESIZING IN PROGRESS...")
total_images = resize()
print("RESIZING COMPLETED!")

print("Successfully Resized " + str(total_images) + " no. of images!!")
# Out:
# COPYING IN PROGRESS...
# COPYING COMPLETED!
# RESIZING IN PROGRESS...
# RESIZING COMPLETED!
# Successfully Resized 100 no. of images!!

# %%
#check image details
import matplotlib.pyplot as plt
from PIL import Image
image = Image.open('archive_new/DisasterModel/train/cyclone/0_resized.jpg')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
plt.imshow(image)
# Out:
# JPEG
# RGB
# (224, 224)

# %% [markdown]
# #AUGMENTATION

# %% [markdown]
# CEFW

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Cyclone/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=928,
                          save_to_dir= r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Cyclone/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
len(os.listdir('archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Cyclone/'))
# Out:
# 5568

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=1350,
                          save_to_dir= r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
len(os.listdir('archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake/'))
# Out:
# 8098

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Flood/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=1073,
                          save_to_dir= r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Flood/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
len(os.listdir('archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Flood/'))
# Out:
# 6438

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Wildfire/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=1077,
                          save_to_dir= r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Wildfire/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
len(os.listdir('archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Wildfire/'))
# Out:
# 6460

# %% [markdown]
# TRAIN

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/train/cyclone/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=400,
                          save_to_dir= r'archive_new/DisasterModel/train/cyclone/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
len(os.listdir('archive_new/DisasterModel/train/cyclone/'))
# Out:
# 2399

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/train/earthquake/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=400,
                          save_to_dir= r'archive_new/DisasterModel/train/earthquake/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
len(os.listdir('archive_new/DisasterModel/train/earthquake/'))
# Out:
# 2399

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/train/flood/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=400,
                          save_to_dir= r'archive_new/DisasterModel/train/flood/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
len(os.listdir('archive_new/DisasterModel/train/flood/'))
# Out:
# 2399

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/train/wildfire/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=400,
                          save_to_dir= r'archive_new/DisasterModel/train/wildfire/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
len(os.listdir('archive_new/DisasterModel/train/wildfire/'))
# Out:
# 2400

# %% [markdown]
# VALIDATION

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/validation/cyclone/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=100,
                          save_to_dir= r'archive_new/DisasterModel/validation/cyclone/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/validation/earthquake/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=100,
                          save_to_dir= r'archive_new/DisasterModel/validation/earthquake/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/validation/flood/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=100,
                          save_to_dir= r'archive_new/DisasterModel/validation/flood/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
        rotation_range = 40,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        brightness_range = (0.5, 1.5))
import numpy as np
import os
from PIL import Image
image_directory = r'archive_new/DisasterModel/validation/wildfire/'
SIZE = 224
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
    if (image_name.split('.')[1] == 'jpg'):        
        image = io.imread(image_directory + image_name)        
        image = Image.fromarray(image, 'RGB')        
        image = image.resize((SIZE,SIZE)) 
        dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=100,
                          save_to_dir= r'archive_new/DisasterModel/validation/wildfire/',
                          save_prefix='dr',
                          save_format='jpg'):    
    i += 1    
    if i > 4:        
        break

# %%
import os
len(os.listdir('archive_new/DisasterModel/validation/cyclone'))
# Out:
# 600

# %%
import os
import importlib
#from paths_creating_and_images_copying import * ## once you have previous script downloaded, no path are needed below
import numpy as np
from datetime import datetime
import json
import keras
from keras import layers
from keras import models
from keras import Model
#from keras import optimizers
from tensorflow.keras import optimizers
from keras.models import load_model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras import callbacks
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import random
import cv2 as cv

# %%
## paths

model_dir = 'archive_new/DisasterModel'

cyclone_dir = r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Cyclone'
earthquake_dir = r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Earthquake'
flood_dir = r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Flood'
wildfire_dir = r'archive_new/DisasterModel/Cyclone_Wildfire_Flood_Earthquake_Dataset/Wildfire'


train_dir = os.path.join(model_dir, 'train')
validation_dir = os.path.join(model_dir, 'validation')
test_dir = os.path.join(model_dir, 'test')

train_dir_c = os.path.join(train_dir, 'cyclone')
train_dir_e = os.path.join(train_dir, 'earthquake')
train_dir_f = os.path.join(train_dir, 'flood')
train_dir_w = os.path.join(train_dir, 'wildfire')

validation_dir_c = os.path.join(validation_dir, 'cyclone')
validation_dir_e = os.path.join(validation_dir, 'earthquake')
validation_dir_f = os.path.join(validation_dir, 'flood')
validation_dir_w = os.path.join(validation_dir, 'wildfire')

test_dir_c = os.path.join(test_dir, 'cyclone')
test_dir_e = os.path.join(test_dir, 'earthquake')
test_dir_f = os.path.join(test_dir, 'flood')
test_dir_w = os.path.join(test_dir, 'wildfire')

print('Check if samples are of same size:\n\nTrain:')
print(len(os.listdir(train_dir_c)), len(os.listdir(train_dir_e)), len(os.listdir(train_dir_f)), len(os.listdir(train_dir_w)))
print('Validation:')
print(len(os.listdir(validation_dir_c)), len(os.listdir(validation_dir_e)), len(os.listdir(validation_dir_f)), len(os.listdir(validation_dir_w)))
print('Test:')
print(len(os.listdir(test_dir_c)), len(os.listdir(test_dir_e)), len(os.listdir(test_dir_f)), len(os.listdir(test_dir_w)))
# Out:
# Check if samples are of same size:
#
# Train:
# 2399 2399 2399 2400
# Validation:
# 600 600 600 600
# Test:
# 100 100 100 100

# %%
model = None

model_path = 'archive/best_model.h5'
model_history_path = 'archive/history'

model_exists = os.path.exists(model_path)
history_exists = os.path.exists(model_history_path)

if model_exists:
    model = load_model(model_path)

else:
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation = 'relu', input_shape= (180, 180, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation = 'relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation= 'relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation= 'relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(256, (3, 3), activation = 'relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(512, activation = 'relu'))
    model.add(layers.Dense(4, activation = 'softmax'))

#keras.backend.clear_session()
model.summary()

if not model_exists:
    model.compile(optimizer=optimizers.RMSprop(lr=1e-4), loss='categorical_crossentropy', metrics=['acc'])


train_datagen = ImageDataGenerator(rescale= 1./255,rotation_range= 40,width_shift_range= .2,height_shift_range= .2,shear_range= .2,zoom_range= .2,horizontal_flip= True)

test_datagen = ImageDataGenerator(rescale= 1./255)

train_generator = train_datagen.flow_from_directory(train_dir,target_size= (180, 180),batch_size=32,class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(validation_dir,target_size=(180, 180),batch_size=32,class_mode='categorical')

print('\n\nCheck a size of data/label batches:')
for data_batch, label_batch in train_generator:
    print('data batch size:', data_batch.shape)
    print('label batch size:', label_batch.shape)
    break

es = EarlyStopping(monitor='val_acc', mode='max', verbose=1, patience=6)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_1 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_1 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dropout_1 (Dropout)         (None, 1152)              0
#
# ...

# %%
history = None

if history_exists:
    with open(model_history_path, 'r') as json_file:
        history = json.load(json_file)
else:
    history = model.fit_generator(train_generator,steps_per_epoch=150, epochs=100, validation_data=validation_generator, validation_steps=50, callbacks=[es, mc]) ##in callback one can put tensorboard_callback once lines 114 and 117 are run

    
## with open(model_history_path, 'w') as json_file:
##     json.dump(str(history.history), json_file)

# %%
model_dir = 'archive/DisasterModel'
test_dir = os.path.join(model_dir, 'test')

best_model = 'archive/best_model.h5'

label_names = {0: 'cyclone', 1: 'earthquake', 2: 'flood', 3: 'wildfire'}

model = load_model(best_model)

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(test_dir, target_size=(180, 180), batch_size=1)

print(len(test_generator)) # [] batch_nr, [] data/labels, [] img_nr, [][] dims, [] channels

loss_test, acc_test = model.evaluate(test_generator)

print('\nThe accuracy of the model is:', str(np.round(acc_test, 2)),'%')
# Out:
# Found 400 images belonging to 4 classes.
# 400
# 400/400 [==============================] - 18s 44ms/step - loss: 0.4475 - acc: 0.8400
#
# The accuracy of the model is: 0.84 %

# %%
def run_prediction():
    n = 331
    plt.figure(figsize=(15, 15))
    for i in range(9):
        plt.subplot(n)
        idx = random.randint(0, len(test_generator)-1)
        predict = model.predict(test_generator[idx][0])
        plt.imshow(test_generator[idx][0][0])
        plt.title(label_names[np.argmax(predict)])
        n += 1

# %%
run_prediction()

# %%
best_model = 'archive/best_model.h5'
model = load_model(best_model)

sample_datagen = ImageDataGenerator(rescale = 1./255)
sample_dir = r'archive/DisasterModel'

sample_generator = sample_datagen.flow_from_directory(sample_dir, target_size=(180, 180), batch_size=1)

def run_visualisation():

    i = random.randint(0, len(sample_generator) - 1)

    plt.figure(figsize=(10, 10))
    predict = model.predict(sample_generator[i][0])
    title ='The below image should present the ' + str(label_names[np.argmax(predict)]) +'\n'
    plt.title(title, fontsize=20)
    plt.imshow(sample_generator[i][0][0])
    plt.show()


    layer_outputs = [layer.output for layer in model.layers]
    activation_model = Model(inputs=model.input, outputs=layer_outputs)
    activations = activation_model.predict(sample_generator[i][0])

    def display_activation(activations, col_size, row_size, act_index):
        activation = activations[act_index]
        activation_index=0
        fig, ax = plt.subplots(row_size, col_size, figsize=(15, 15))
        title1 = 'Images from the layer ' + str(act_index)
        fig.suptitle(title1, fontsize=16)
        for row in range(0, row_size):
            for col in range(0, col_size):
                ax[row][col].imshow(activation[0, :, :, activation_index], cmap='gray')
                activation_index += 1

    display_activation(activations, 2, 2, 0) ## 4 images from the 1st layer
    plt.show()

    display_activation(activations, 2, 2, 1) ## 4 images from the 2nd layer
    plt.show()

    display_activation(activations, 2, 2, 3) ## 4 images from the 4th layer
    plt.show()

    display_activation(activations, 3, 3, 5) ## 9 images from the 6th layer
    plt.show()
# Out:
# Found 6828 images belonging to 4 classes.

# %%
run_visualisation()

# %%
keras_file = 'MLmodel.h5'
keras.models.save_model(model,keras_file)

# %%
from tensorflow import lite
import tensorflow as tf

# %%
converter = tf.compat.v1.lite.TFLiteConverter.from_keras_model_file(keras_file)
tflite_model = converter.convert()
open("converted_model.tflite", "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpp0r7y0mk/assets
# INFO:tensorflow:Assets written to: /tmp/tmpp0r7y0mk/assets
# INFO:tensorflow:Restoring parameters from /tmp/tmpp0r7y0mk/variables/variables
# INFO:tensorflow:Restoring parameters from /tmp/tmpp0r7y0mk/variables/variables
# INFO:tensorflow:The given SavedModel MetaGraphDef contains SignatureDefs with the following keys: {'serving_default', '__saved_model_init_op'}
# INFO:tensorflow:The given SavedModel MetaGraphDef contains SignatureDefs with the following keys: {'serving_default', '__saved_model_init_op'}
# INFO:tensorflow:input tensors info:
# INFO:tensorflow:input tensors info:
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: conv2d_1_input
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: conv2d_1_input
# INFO:tensorflow: tensor name: serving_default_conv2d_1_input:0, shape: (-1, 180, 180, 3), type: DT_FLOAT
# ...
